# %%
import json

# %%
file = open("/Users/shouqmohammed/Downloads/points-of-sale-transactions-feb-21.json")

# %%
json.load(file)
# Out:
# [{'112.0': '5', '': '', 'Main': '$B$456'},
#  {'112.0': '5', '': '', 'Main': '$B$458'},
#  {'112.0': '5', '': '', 'Main': '$B$457'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$49'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$46'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$44'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$41'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$38'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$34'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$32'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$30'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$28'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$25'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$23'},
#  {'112.0': '7-3', '': 0, 'Main': '$AW$20'},
#  {'112.0': '7-3', '': 0, 'Main': '$AW$18'},
#  {'112.0': '7-3', '': 0, 'Main': '$AW$15'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$16'},
#  {'112.0': '7-3', '': 0, 'Main': '$C$40'},
#  {'112.0': '7-3', '': 0, 'Main': '$BE$20'},
#  {'112.0': '7-3', '': 0, 'Main': '$AW$49'},
# ...
