# %%
#current working dictory:
import os
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\python'

# %%
import pandas as pd
import numpy as np

# %%
#load the Excel file which has extension of .xlsx
data = pd.read_excel("c:/users/hp/Downloads/electricity-consumption-2011-2020.xlsx")

# %%
data.head()
# Out:
#      Year consumbiion category    Region  Electricity consumption (GWh)
# 0  2011.0          Residential   Central                        37042.0
# 1  2011.0          Residential   Eastern                        21311.0
# 2  2011.0          Residential  Southern                        12172.0
# 3  2011.0          Residential   Western                        39099.0
# 4  2011.0           Commercial   Central                        11503.0

# %%
#show the first 5 row using dataframe.head()method Print("the first 5 row of the dataframe")
data.head(7)
# Out:
#      Year consumbiion category    Region  Electricity consumption (GWh)
# 0  2011.0          Residential   Central                        37042.0
# 1  2011.0          Residential   Eastern                        21311.0
# 2  2011.0          Residential  Southern                        12172.0
# 3  2011.0          Residential   Western                        39099.0
# 4  2011.0           Commercial   Central                        11503.0
# 5  2011.0           Commercial   Eastern                         6767.0
# 6  2011.0           Commercial  Southern                         2711.0

# %%
#Print("the last 10 row of the dataframe\n")
data.tail(20)
# Out:
#        Year                               consumbiion category    Region  \
# 184  2020.0                                         Commercial   Central
# 185  2020.0                                         Commercial   Eastern
# 186  2020.0                                         Commercial  Southern
# 187  2020.0                                         Commercial   Western
# 188  2020.0                                         Government   Central
# 189  2020.0                                         Government   Eastern
# 190  2020.0                                         Government  Southern
# 191  2020.0                                         Government   Western
# 192  2020.0                                         Industrial   Central
# 193  2020.0                                         Industrial   Eastern
# 194  2020.0                                         Industrial  Southern
# 195  2020.0                                         Industrial   Western
# ...

# %%
headers = ["Year","consumbiion category","Region","Electricity consumption (GWh)"]
print("headers\n", headers)
# Out:
# headers
#  ['Year', 'consumbiion category', 'Region', 'Electricity consumption (GWh)']

# %%
data.columns = headers
data.head(15)
# Out:
#       Year consumbiion category    Region  Electricity consumption (GWh)
# 0   2011.0          Residential   Central                        37042.0
# 1   2011.0          Residential   Eastern                        21311.0
# 2   2011.0          Residential  Southern                        12172.0
# 3   2011.0          Residential   Western                        39099.0
# 4   2011.0           Commercial   Central                        11503.0
# 5   2011.0           Commercial   Eastern                         6767.0
# 6   2011.0           Commercial  Southern                         2711.0
# 7   2011.0           Commercial   Western                        12138.0
# 8   2011.0           Government   Central                         8759.0
# 9   2011.0           Government   Eastern                         6844.0
# 10  2011.0           Government  Southern                         2269.0
# 11  2011.0           Government   Western                         6269.0
# ...

# %%
#data1=data.replace('?',np.NoN)

# %%
#data=data1.dropna(subset=["age"], axis=0)
data.head(20)
# Out:
#       Year consumbiion category    Region  Electricity consumption (GWh)
# 0   2011.0          Residential   Central                        37042.0
# 1   2011.0          Residential   Eastern                        21311.0
# 2   2011.0          Residential  Southern                        12172.0
# 3   2011.0          Residential   Western                        39099.0
# 4   2011.0           Commercial   Central                        11503.0
# 5   2011.0           Commercial   Eastern                         6767.0
# 6   2011.0           Commercial  Southern                         2711.0
# 7   2011.0           Commercial   Western                        12138.0
# 8   2011.0           Government   Central                         8759.0
# 9   2011.0           Government   Eastern                         6844.0
# 10  2011.0           Government  Southern                         2269.0
# 11  2011.0           Government   Western                         6269.0
# ...

# %%
print(data.columns)
# Out:
# Index(['Year', 'consumbiion category', 'Region',
#        'Electricity consumption (GWh)'],
#       dtype='object')

# %%
#describe all the columns in "data"
data.describe(include = "all")
# Out:
#                Year consumbiion category   Region  \
# count    200.000000                  202      200
# unique          NaN                    7        4
# top             NaN          Residential  Central
# freq            NaN                   40       50
# mean    2015.500000                  NaN      NaN
# std        2.879489                  NaN      NaN
# min     2011.000000                  NaN      NaN
# 25%     2013.000000                  NaN      NaN
# 50%     2015.500000                  NaN      NaN
# 75%     2018.000000                  NaN      NaN
# max     2020.000000                  NaN      NaN
#
#         Electricity consumption (GWh)
# count                      200.000000
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean                     13899.995000
# std                      13453.303656
# min                        167.000000
# 25%                       4315.250000
# ...
