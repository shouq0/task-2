# %%
import json

# %%
file = open("/Users/shouqmohammed/Downloads/number-of-smes-2022-q1.json")

# %%
json.load(file)
# Out:
# [{'عدد المنشآت متناهية الصغر ': 124.0,
#   'عدد المنشآت الصغيرة ': 30.0,
#   'النشاط الاقتصادي ': 'أبحاث الإعلان والسوق',
#   'عدد المنشآت المتوسطة ': 1.0,
#   'عدد المنشآت الكبيرة ': 0.0,
#   'عدد المنشآت ': 155.0,
#   'المنطقة ': 'مكتب المنطقة الشرقية',
#   'السنة': 2022.0,
#   'الربع ': 1.0},
#  {'عدد المنشآت متناهية الصغر ': 302.0,
#   'عدد المنشآت الصغيرة ': 74.0,
#   'النشاط الاقتصادي ': 'إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية',
#   'عدد المنشآت المتوسطة ': 9.0,
#   'عدد المنشآت الكبيرة ': 1.0,
#   'عدد المنشآت ': 386.0,
#   'المنطقة ': 'مكتب المنطقة الشرقية',
#   'السنة': 2022.0,
#   'الربع ': 1.0},
#  {'عدد المنشآت متناهية الصغر ': 201.0,
#   'عدد المنشآت الصغيرة ': 72.0,
#   'النشاط الاقتصادي ': 'إصلاح وتركيب الآلات والمعدات',
#   'عدد المنشآت المتوسطة ': 6.0,
#   'عدد المنشآت الكبيرة ': 1.0,
#   'عدد المنشآت ': 280.0,
#   'المنطقة ': 'مكتب المنطقة الشرقية',
#   'السنة': 2022.0,
#   'الربع ': 1.0},
#  {'عدد المنشآت متناهية الصغر ': 30.0,
# ...
