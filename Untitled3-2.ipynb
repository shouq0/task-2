# %%
#current working directory
import os
os.getcwd()
# Out:
# '/Users/shouqmohammed/Downloads/task 2'

# %%
import pandas as pd

# %%
#load the Excel file which has extension of .xlsx
data = pd.read_excel("number-of-smes-2022-q1.xlsx")

# %%
data.head()
# Out:
#    السنة  الربع               المنطقة   \
# 0   2022       1  مكتب المنطقة الشرقية
# 1   2022       1  مكتب المنطقة الشرقية
# 2   2022       1  مكتب المنطقة الشرقية
# 3   2022       1  مكتب المنطقة الشرقية
# 4   2022       1  مكتب المنطقة الشرقية
#
#                                    النشاط الاقتصادي   \
# 0                               أبحاث الإعلان والسوق
# 1       إصلاح أجهزة الحاسوب والسلع الشخصية والمنزلية
# 2                       إصلاح وتركيب الآلات والمعدات
# 3  أنشطة أنتاج الأفلام والبرامج التلفزيونية والتس...
# 4                             أنشطة الأمن والتحقيقات
#
#    عدد المنشآت متناهية الصغر   عدد المنشآت الصغيرة   عدد المنشآت المتوسطة   \
# 0                         124                    30                      1
# 1                         302                    74                      9
# 2                         201                    72                      6
# 3                          30                     4                      0
# ...

# %%
data.tail()
# Out:
#       السنة  الربع           المنطقة   \
# 5308   2022       1  مكتب منطقة نجران
# 5309   2022       1  مكتب منطقة نجران
# 5310   2022       1  مكتب منطقة نجران
# 5311   2022       1  مكتب منطقة نجران
# 5312   2022       1  مكتب منطقة نجران
#
#                                       النشاط الاقتصادي   \
# 5308                         صنع منتجات المطاط واللدائن
# 5309                صنع منتجات المعادن اللافلزية الأخرى
# 5310  صنع منتجات المعادن المشكلة ( باستثناء الآلات و...
# 5311                        صيد الأسماك وتربية المائيات
# 5312  وكالات السفر ومشغّلو الجولات السياحية وخدمات ا...
#
#       عدد المنشآت متناهية الصغر   عدد المنشآت الصغيرة   عدد المنشآت المتوسطة   \
# 5308                          21                     2                      0
# 5309                          66                    31                      9
# 5310                         175                    14                      4
# ...
